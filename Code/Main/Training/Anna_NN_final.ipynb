# %% [markdown]
# This notebook contains Anna's NN models

# %% [markdown]
# # A. Importing Helper Functions and Variables

# %% [markdown]
# Helper functions and global variables can be found [here]('http://localhost:8888/lab/tree/Code/Helper/config.py')

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import tensorflow as tf
import seaborn as sns
import sys 

from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import EfficientNetV2L
from keras import metrics
from tensorflow.keras.metrics import BinaryAccuracy, AUC, Precision, Recall, TrueNegatives, TruePositives, FalsePositives, FalseNegatives
from sklearn.model_selection import train_test_split

# For reproducibility
np.random.seed(42)
# Source: https://www.tensorflow.org/api_docs/python/tf/keras/utils/set_random_seed
tf.keras.utils.set_random_seed(42)

# %%
# Importing global variables
sys.path.append('../../Helper')
import config
# Out:
# Metal device set to: Apple M2 Max

# %% [markdown]
# ### Find Shape of Images

# %% [markdown]
# * Each image is a 256 X 256 jpg image of human face either real or fake

# %%
# Create base_path variable for continued usage
base_path = '../../../Dataset/'

# Get the shape of a sample image
image_shape = img_to_array(load_img(base_path + 'Train/Real/real_0.jpg')).shape

# Print shape of sample image
print(image_shape)

# Set variable for width and height of image
w = image_shape[0]
h = image_shape[1]
# Out:
# (256, 256, 3)

# %% [markdown]
# ### Import Train, Validation, and Test dataset from Directory
#
# * Code modified from: Lesson 8.06-CNN

# %%
train = image_dataset_from_directory(
    base_path + '/Train',
    image_size=(w,h),
    batch_size=32,
    seed=42,
    label_mode='binary'
)

val = image_dataset_from_directory(
    base_path + '/Validation',
    image_size=(w,h),
    batch_size=32,
    seed=42,
    label_mode='binary'
)

test = image_dataset_from_directory(
    base_path + '/Test',
    image_size=(w,h),
    batch_size=32,
    label_mode='binary'
)
# Out:
# Found 140010 files belonging to 2 classes.
# Found 39455 files belonging to 2 classes.
# Found 10905 files belonging to 2 classes.

# %%
# Check to see the classes and example files in train dataset
train.class_names, train.file_paths[:5]
# Out:
# (['Fake', 'Real'],
#  ['../../../Dataset//Train/Fake/fake_22599.jpg',
#   '../../../Dataset//Train/Fake/fake_54816.jpg',
#   '../../../Dataset//Train/Fake/fake_56285.jpg',
#   '../../../Dataset//Train/Real/real_8796.jpg',
#   '../../../Dataset//Train/Fake/fake_21378.jpg'])

# %%
# Check to see train is a BatchDataset
type(train)
# Out:
# tensorflow.python.data.ops.batch_op._BatchDataset

# %% [markdown]
# # B. Training CNN models

# %% [markdown]
# ## Model 1

# %% [markdown]
# Model 1 is a CNN model with three types of layers without any regularizations:
# * Convolutional layer
# * Pooling layer
# * Densely Connected layer
#
# In each layer, 64 neurons were used. This value was chosen arbitrarily to gage the performance of a simple CNN model.

# %%
model1 = Sequential()

model1.add(layers.Input(shape = (h,w,3)))
#normalize pixel and preprocess images in network
model1.add(layers.Rescaling(1./255))


#First Convolution layer
model1.add(Conv2D(64, (3,3), activation = 'relu'))
#MaxPooling
model1.add(MaxPooling2D(pool_size = (2,2)))


# 2nd Convolution layer
model1.add(Conv2D(64, (3,3), activation = 'relu'))
model1.add(MaxPooling2D(pool_size=(2,2)))


#To feed this into our model, we need to flatten
model1.add(Flatten())

#Fully connected layer
# 1 Hidden Layer
model1.add(Dense(64, activation = 'relu'))

#Output Layer
model1.add(Dense(1, activation = 'sigmoid'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 246016)            0
#
#  dense (Dense)               (None, 64)                15745088
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 15,783,873
# Trainable params: 15,783,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile
model1.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc',  
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
# Let's train the model by fitting it
h1 = model1.fit(train, validation_data = val, epochs = 10)
# Out:
# Epoch 1/10
# 4376/4376 [==============================] - 864s 197ms/step - loss: 0.4232 - acc: 0.8016 - precision_6: 0.7887 - recall_6: 0.8238 - auc_6: 0.8869 - false_negatives_6: 12331.0000 - false_positives_6: 15452.0000 - true_negatives_6: 54549.0000 - true_positives_6: 57670.0000 - val_loss: 0.4248 - val_acc: 0.7998 - val_precision_6: 0.7888 - val_recall_6: 0.8210 - val_auc_6: 0.8856 - val_false_negatives_6: 3541.0000 - val_false_positives_6: 4351.0000 - val_true_negatives_6: 15290.0000 - val_true_positives_6: 16246.0000
# Epoch 2/10
# 4376/4376 [==============================] - 859s 196ms/step - loss: 0.3120 - acc: 0.8612 - precision_6: 0.8499 - recall_6: 0.8773 - auc_6: 0.9393 - false_negatives_6: 8590.0000 - false_positives_6: 10845.0000 - true_negatives_6: 59156.0000 - true_positives_6: 61411.0000 - val_loss: 0.4197 - val_acc: 0.8123 - val_precision_6: 0.8472 - val_recall_6: 0.7637 - val_auc_6: 0.9002 - val_false_negatives_6: 4676.0000 - val_false_positives_6: 2725.0000 - val_true_negatives_6: 16916.0000 - val_true_positives_6: 15111.0000
# Epoch 3/10
# 4376/4376 [==============================] - 856s 196ms/step - loss: 0.2453 - acc: 0.8951 - precision_6: 0.8856 - recall_6: 0.9075 - auc_6: 0.9629 - false_negatives_6: 6477.0000 - false_positives_6: 8204.0000 - true_negatives_6: 61797.0000 - true_positives_6: 63524.0000 - val_loss: 0.3786 - val_acc: 0.8376 - val_precision_6: 0.8694 - val_recall_6: 0.7960 - val_auc_6: 0.9242 - val_false_negatives_6: 4036.0000 - val_false_positives_6: 2366.0000 - val_true_negatives_6: 17275.0000 - val_true_positives_6: 15751.0000
# Epoch 4/10
# 4376/4376 [==============================] - 855s 195ms/step - loss: 0.1943 - acc: 0.9197 - precision_6: 0.9114 - recall_6: 0.9299 - auc_6: 0.9766 - false_negatives_6: 4905.0000 - false_positives_6: 6332.0000 - true_negatives_6: 63669.0000 - true_positives_6: 65096.0000 - val_loss: 0.3396 - val_acc: 0.8603 - val_precision_6: 0.8380 - val_recall_6: 0.8946 - val_auc_6: 0.9390 - val_false_negatives_6: 2086.0000 - val_false_positives_6: 3421.0000 - val_true_negatives_6: 16220.0000 - val_true_positives_6: 17701.0000
# Epoch 5/10
# 4376/4376 [==============================] - 860s 196ms/step - loss: 0.1489 - acc: 0.9401 - precision_6: 0.9315 - recall_6: 0.9500 - auc_6: 0.9861 - false_negatives_6: 3498.0000 - false_positives_6: 4893.0000 - true_negatives_6: 65108.0000 - true_positives_6: 66503.0000 - val_loss: 0.3734 - val_acc: 0.8622 - val_precision_6: 0.8363 - val_recall_6: 0.9020 - val_auc_6: 0.9390 - val_false_negatives_6: 1940.0000 - val_false_positives_6: 3493.0000 - val_true_negatives_6: 16148.0000 - val_true_positives_6: 17847.0000
# Epoch 6/10
# 4376/4376 [==============================] - 857s 196ms/step - loss: 0.1107 - acc: 0.9557 - precision_6: 0.9485 - recall_6: 0.9637 - auc_6: 0.9921 - false_negatives_6: 2542.0000 - false_positives_6: 3661.0000 - true_negatives_6: 66340.0000 - true_positives_6: 67459.0000 - val_loss: 0.4367 - val_acc: 0.8573 - val_precision_6: 0.8212 - val_recall_6: 0.9147 - val_auc_6: 0.9342 - val_false_negatives_6: 1687.0000 - val_false_positives_6: 3941.0000 - val_true_negatives_6: 15700.0000 - val_true_positives_6: 18100.0000
# Epoch 7/10
# 4376/4376 [==============================] - 857s 196ms/step - loss: 0.0833 - acc: 0.9670 - precision_6: 0.9612 - recall_6: 0.9734 - auc_6: 0.9954 - false_negatives_6: 1861.0000 - false_positives_6: 2754.0000 - true_negatives_6: 67247.0000 - true_positives_6: 68140.0000 - val_loss: 0.5359 - val_acc: 0.8566 - val_precision_6: 0.8286 - val_recall_6: 0.9005 - val_auc_6: 0.9257 - val_false_negatives_6: 1969.0000 - val_false_positives_6: 3686.0000 - val_true_negatives_6: 15955.0000 - val_true_positives_6: 17818.0000
# Epoch 8/10
# 4376/4376 [==============================] - 857s 196ms/step - loss: 0.0647 - acc: 0.9742 - precision_6: 0.9697 - recall_6: 0.9789 - auc_6: 0.9971 - false_negatives_6: 1476.0000 - false_positives_6: 2143.0000 - true_negatives_6: 67858.0000 - true_positives_6: 68525.0000 - val_loss: 0.5695 - val_acc: 0.8609 - val_precision_6: 0.8369 - val_recall_6: 0.8979 - val_auc_6: 0.9259 - val_false_negatives_6: 2021.0000 - val_false_positives_6: 3462.0000 - val_true_negatives_6: 16179.0000 - val_true_positives_6: 17766.0000
# Epoch 9/10
# 4376/4376 [==============================] - 857s 196ms/step - loss: 0.0523 - acc: 0.9797 - precision_6: 0.9760 - recall_6: 0.9835 - auc_6: 0.9980 - false_negatives_6: 1157.0000 - false_positives_6: 1692.0000 - true_negatives_6: 68309.0000 - true_positives_6: 68844.0000 - val_loss: 0.6751 - val_acc: 0.8587 - val_precision_6: 0.8308 - val_recall_6: 0.9023 - val_auc_6: 0.9210 - val_false_negatives_6: 1933.0000 - val_false_positives_6: 3637.0000 - val_true_negatives_6: 16004.0000 - val_true_positives_6: 17854.0000
# Epoch 10/10
# 4376/4376 [==============================] - 856s 196ms/step - loss: 0.0464 - acc: 0.9830 - precision_6: 0.9810 - recall_6: 0.9851 - auc_6: 0.9982 - false_negatives_6: 1044.0000 - false_positives_6: 1335.0000 - true_negatives_6: 68666.0000 - true_positives_6: 68957.0000 - val_loss: 0.7281 - val_acc: 0.8600 - val_precision_6: 0.8487 - val_recall_6: 0.8774 - val_auc_6: 0.9187 - val_false_negatives_6: 2425.0000 - val_false_positives_6: 3096.0000 - val_true_negatives_6: 16545.0000 - val_true_positives_6: 17362.0000

# %%
# Evaluate last epoch Train and Val Loss and Accuracy scores
print(f"Train Loss: {h1.history['loss'][-1]}\n\
Val Loss: {h1.history['val_loss'][-1]}\n\
Train Acc:{h1.history['acc'][-1]}\n\
Val Acc:{h1.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.04641798883676529
# Val Loss: 0.7281487584114075
# Train Acc: 0.9830074310302734
# Test Acc:0.8599725961685181

# %% [markdown]
# **Loss** values indicate the summation of errors between the predicted and actual values. A lower loss value indicates a better fit.
#
# **Accuracy** values indicate how well model predicts the correct class (Real or Fake). A higher accuracy value indicates a better performing model.
#
# <u>Model 1 Performance</u>
# * The Training loss (0.046) is significantly lower than the validation loss (0.728). This model may be overfitting to the training data since it performs better on the training data, but less well on unseen validation data.
# * The Training accuracy (98.3%) is higher than the validation accuracy (86.0%). This further suggests the presence of overfitting, as the model is not generalizing well to the validation data.

# %%
# Append last epoch scores to model_eval_anna.csv 
model_scores_to_csv(model1, h1, 'model_1')

# %% [markdown]
# ###  EDA function

# %%
config.graph_me(h1, ['acc'])

plt.savefig('model1_r.png')

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h1.history['loss'],label='Train Loss')
plt.plot(h1.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 1 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h1.history['acc'],label='Train Accuracy')
plt.plot(h1.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 1 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model1.png')

# Display the plot
plt.show();

# %%
# serialize model to JSON
anna_model1_json = model1.to_json()
with open("anna_model1.json", "w") as json_file:
    json_file.write(anna_model1_json)

# serialize weights to HDF5
model1.save_weights("anna_model1.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Save model
model1.save('anna_model1_complete.h5')

# %% [markdown]
# ## Model 2 - Larger Neurons

# %% [markdown]
# In the 2nd model, larger neurons were utilized and regularizations were added to try to combat the model overfitting to the training set.
# * Regularization techniques used:
#     * **BatchNormalization:** helps stabilize and accelerate the training process by normalizing the activations. This helps the model learn more effectively. It also has a slight regularization effect in that it helps reduce overfitting and improve the model's generalize to new/unseen data.
#         * BatchNormalization was applied *before* the activation function. [(Source)](https://machinelearningmastery.com/batch-normalization-for-training-of-deep-neural-networks/)
#     * **Dropout:**  during training, some number of layer outputs are randomly dropped. This also helps with overfitting in the model.

# %%
model2 = Sequential()

model2.add(layers.Input(shape = (h,w,3)))
#normalize pixel and preprocess images in network
model2.add(layers.Rescaling(1./255))


#First Convolution layer
model2.add(Conv2D(64, (3,3), activation = 'relu'))

#MaxPooling
model2.add(MaxPooling2D(pool_size = (2,2)))
model2.add(BatchNormalization())

# 2nd Convolution layer
model2.add(Conv2D(128, (3,3), activation = 'relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(BatchNormalization())
model2.add(layers.Dropout(0.2))

#To feed this into our model, we need to flatten
model2.add(Flatten())

#Fully connected layer
# 1 Hidden Layer
model2.add(Dense(256, activation = 'relu'))
model2.add(BatchNormalization())

#Output Layer
model2.add(Dense(1, activation = 'sigmoid'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_2 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  batch_normalization (BatchN  (None, 127, 127, 64)     256
#  ormalization)
#
#  conv2d_3 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_3 (MaxPooling  (None, 62, 62, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 62, 62, 128)      512
#  hNormalization)
#
#  dropout (Dropout)           (None, 62, 62, 128)       0
#
#  flatten_1 (Flatten)         (None, 492032)            0
#
#  dense_2 (Dense)             (None, 256)               125960448
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 126,038,145
# Trainable params: 126,037,249
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
model2.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
# Let's train the model by fitting it
h2 = model2.fit(train, validation_data = val, epochs = 10)
# Out:
# Epoch 1/10
# 2023-05-20 01:13:17.417227: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 4376/4376 [==============================] - 1645s 376ms/step - loss: 0.3072 - acc: 0.8651 - precision_1: 0.8578 - recall_1: 0.8753 - auc_1: 0.9422 - false_negatives_1: 8729.0000 - false_positives_1: 10157.0000 - true_negatives_1: 59851.0000 - true_positives_1: 61273.0000 - val_loss: 0.2535 - val_acc: 0.8928 - val_precision_1: 0.9085 - val_recall_1: 0.8744 - val_auc_1: 0.9619 - val_false_negatives_1: 2487.0000 - val_false_positives_1: 1744.0000 - val_true_negatives_1: 17911.0000 - val_true_positives_1: 17313.0000
# Epoch 2/10
# 4376/4376 [==============================] - 1646s 376ms/step - loss: 0.1483 - acc: 0.9406 - precision_1: 0.9358 - recall_1: 0.9460 - auc_1: 0.9863 - false_negatives_1: 3778.0000 - false_positives_1: 4543.0000 - true_negatives_1: 65465.0000 - true_positives_1: 66224.0000 - val_loss: 0.2408 - val_acc: 0.9022 - val_precision_1: 0.8797 - val_recall_1: 0.9326 - val_auc_1: 0.9667 - val_false_negatives_1: 1335.0000 - val_false_positives_1: 2524.0000 - val_true_negatives_1: 17131.0000 - val_true_positives_1: 18465.0000
# Epoch 3/10
# 4376/4376 [==============================] - 1642s 375ms/step - loss: 0.0836 - acc: 0.9674 - precision_1: 0.9649 - recall_1: 0.9701 - auc_1: 0.9954 - false_negatives_1: 2091.0000 - false_positives_1: 2471.0000 - true_negatives_1: 67537.0000 - true_positives_1: 67911.0000 - val_loss: 0.2484 - val_acc: 0.9152 - val_precision_1: 0.9168 - val_recall_1: 0.9140 - val_auc_1: 0.9704 - val_false_negatives_1: 1703.0000 - val_false_positives_1: 1642.0000 - val_true_negatives_1: 18013.0000 - val_true_positives_1: 18097.0000
# Epoch 4/10
# 4376/4376 [==============================] - 1642s 375ms/step - loss: 0.0602 - acc: 0.9776 - precision_1: 0.9758 - recall_1: 0.9794 - auc_1: 0.9974 - false_negatives_1: 1441.0000 - false_positives_1: 1697.0000 - true_negatives_1: 68311.0000 - true_positives_1: 68561.0000 - val_loss: 0.2307 - val_acc: 0.9230 - val_precision_1: 0.9255 - val_recall_1: 0.9206 - val_auc_1: 0.9739 - val_false_negatives_1: 1573.0000 - val_false_positives_1: 1467.0000 - val_true_negatives_1: 18188.0000 - val_true_positives_1: 18227.0000
# Epoch 5/10
# 4376/4376 [==============================] - 1642s 375ms/step - loss: 0.0454 - acc: 0.9837 - precision_1: 0.9829 - recall_1: 0.9845 - auc_1: 0.9983 - false_negatives_1: 1083.0000 - false_positives_1: 1200.0000 - true_negatives_1: 68808.0000 - true_positives_1: 68919.0000 - val_loss: 0.3152 - val_acc: 0.9182 - val_precision_1: 0.9031 - val_recall_1: 0.9376 - val_auc_1: 0.9669 - val_false_negatives_1: 1235.0000 - val_false_positives_1: 1991.0000 - val_true_negatives_1: 17664.0000 - val_true_positives_1: 18565.0000
# Epoch 6/10
# 4376/4376 [==============================] - 1622s 371ms/step - loss: 0.0441 - acc: 0.9840 - precision_1: 0.9831 - recall_1: 0.9849 - auc_1: 0.9984 - false_negatives_1: 1057.0000 - false_positives_1: 1182.0000 - true_negatives_1: 68826.0000 - true_positives_1: 68945.0000 - val_loss: 0.5460 - val_acc: 0.8863 - val_precision_1: 0.9299 - val_recall_1: 0.8364 - val_auc_1: 0.9422 - val_false_negatives_1: 3239.0000 - val_false_positives_1: 1248.0000 - val_true_negatives_1: 18407.0000 - val_true_positives_1: 16561.0000
# Epoch 7/10
# 4376/4376 [==============================] - 1610s 368ms/step - loss: 0.0365 - acc: 0.9870 - precision_1: 0.9862 - recall_1: 0.9878 - auc_1: 0.9988 - false_negatives_1: 851.0000 - false_positives_1: 968.0000 - true_negatives_1: 69040.0000 - true_positives_1: 69151.0000 - val_loss: 0.2534 - val_acc: 0.9156 - val_precision_1: 0.8889 - val_recall_1: 0.9508 - val_auc_1: 0.9727 - val_false_negatives_1: 975.0000 - val_false_positives_1: 2354.0000 - val_true_negatives_1: 17301.0000 - val_true_positives_1: 18825.0000
# Epoch 8/10
# 4376/4376 [==============================] - 1613s 369ms/step - loss: 0.0297 - acc: 0.9896 - precision_1: 0.9893 - recall_1: 0.9899 - auc_1: 0.9991 - false_negatives_1: 706.0000 - false_positives_1: 752.0000 - true_negatives_1: 69256.0000 - true_positives_1: 69296.0000 - val_loss: 0.3119 - val_acc: 0.9164 - val_precision_1: 0.8916 - val_recall_1: 0.9487 - val_auc_1: 0.9679 - val_false_negatives_1: 1015.0000 - val_false_positives_1: 2283.0000 - val_true_negatives_1: 17372.0000 - val_true_positives_1: 18785.0000
# Epoch 9/10
# 4376/4376 [==============================] - 1610s 368ms/step - loss: 0.0279 - acc: 0.9902 - precision_1: 0.9899 - recall_1: 0.9905 - auc_1: 0.9992 - false_negatives_1: 663.0000 - false_positives_1: 711.0000 - true_negatives_1: 69297.0000 - true_positives_1: 69339.0000 - val_loss: 0.3505 - val_acc: 0.9132 - val_precision_1: 0.8851 - val_recall_1: 0.9505 - val_auc_1: 0.9653 - val_false_negatives_1: 980.0000 - val_false_positives_1: 2443.0000 - val_true_negatives_1: 17212.0000 - val_true_positives_1: 18820.0000
# Epoch 10/10
# 4376/4376 [==============================] - 1611s 368ms/step - loss: 0.0271 - acc: 0.9907 - precision_1: 0.9902 - recall_1: 0.9912 - auc_1: 0.9992 - false_negatives_1: 619.0000 - false_positives_1: 684.0000 - true_negatives_1: 69324.0000 - true_positives_1: 69383.0000 - val_loss: 0.4574 - val_acc: 0.9101 - val_precision_1: 0.8763 - val_recall_1: 0.9557 - val_auc_1: 0.9578 - val_false_negatives_1: 877.0000 - val_false_positives_1: 2670.0000 - val_true_negatives_1: 16985.0000 - val_true_positives_1: 18923.0000

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h2.history['loss'][-1]}\n\
Val Loss: {h2.history['val_loss'][-1]}\n\
Train Acc:{h2.history['acc'][-1]}\n\
Val Acc:{h2.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.02705742046236992
# Val Loss: 0.45739367604255676
# Train Acc: 0.9906935095787048
# Val Acc: 0.9101001620292664

# %% [markdown]
# <u>Model 2 Performance</u>
# * The Training and Validation Loss has both decreased compared to model 1. There still seems to be some overfitting as the validation loss (0.457) is significantly greater than the train loss (0.027).
# * The Training accuracy (99.1%) is higher than the validation accuracy (91.0%).
# * However, both values have increased compared to model 1.
#
# Further methods will need to be explored to help with overfitting.

# %%
def model_scores_to_csv(models, history_list, model_name): 
    #Specified Columns:
    columns = ['train_loss','train_acc','train_precision','train_recall','train_auc','train_fn','train_fp','train_tn','train_tp','val_loss', 'val_acc','val_precision','val_recall','val_auc','val_fn','val_fp','val_tn','val_tp']
    
    if 'model_eval.csv' not in os.listdir('../../Results/'):
        df = pd.DataFrame(columns=columns, index=['models'])
    
        df.to_csv('../../Results/model_eval.csv')
    
    # Get the last epoch values from the history dictionary
    last_epoch_values = [list(values)[-1] for values in history_list.history.values()]

    # Create a dictionary with the model scores and the model name as the index
    model_scores = {col: [val] for col, val in zip(columns, last_epoch_values)}

    # Set the model name as the index in the dictionary
    model_scores['models'] = model_name

    # Create a temporary dataframe with the model scores
    df = pd.DataFrame(model_scores)
    
    df.set_index('models', inplace = True, drop = True)

    # Append the model scores to the CSV file
    df.to_csv('../../Results/model_eval.csv', mode='a', header = False)

    return

# %%
# Append last epoch scores to model_eval.csv 
config.model_scores_to_csv(model2, h2, 'model_2')

# %%
config.graph_me(h2, ['acc'])

plt.savefig('model2_r.png')

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h2.history['loss'],label='Train Loss')
plt.plot(h2.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 2 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h2.history['acc'],label='Train Accuracy')
plt.plot(h2.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 2 Train and Val Accuracy')
plt.ylim(0, 1)


# Save the plot as a PNG image
plt.savefig('model2.png')

plt.show();

# %%
# serialize model to JSON
anna_model2_json = model2.to_json()
with open("anna_model2.json", "w") as json_file:
    json_file.write(anna_model2_json)

# serialize weights to HDF5
model2.save_weights("anna_model2.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Save model
model2.save('anna_model2_complete.h5')

# %% [markdown]
# # Model 3 - Reduce LR on Plateau & Early Stopping

# %% [markdown]
# In the 3rd Model to combat overfitting, two callback functions were applied at the training process:
#
# * **EarlyStopping**: tells the model when the training process to stop. The value to monitor was set to be the `val_loss` in hopes to minimize this metric. The patience was set to 3, which is the number of epochs the training should be stopped if there is no improvement.
#
# * **ReduceLROnPlateau**: tells the model to reduce the learning rate when `val_acc` has stopped improving. The patience was also set to 3 and the factor by which the learning rate will be reduced was set to 0.5 (new_lr = lr * 0.5). The lower bound on the learning rate was set to 0.00001.
#
# These callbacks were utilized in hopes to minimize the `val_loss` and increase the `val_acc`.
#
# Additionally, a second Dropout layer was added in the hidden layer, which nullifies some hidden neurons. This can further help prevent overfitting on the training data.

# %%
# Source: https://keras.io/api/callbacks/reduce_lr_on_plateau/
# Reduce LR when metric has stopped improving
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_acc',
    factor=0.5,
    patience=3,
    verbose=0,
    min_lr=0.00001,
)

# %%
es = EarlyStopping(patience=3, verbose = 1, monitor = 'val_loss')

# %%
model3 = Sequential()

model3.add(layers.Input(shape = (h,w,3)))
#normalize pixel and preprocess images in network
model3.add(layers.Rescaling(1./255))


#First Convolution layer
model3.add(Conv2D(64, (3,3), activation = 'relu'))

#MaxPooling
model3.add(MaxPooling2D(pool_size = (2,2)))
model3.add(BatchNormalization())

# 2nd Convolution layer
model3.add(Conv2D(128, (3,3), activation = 'relu'))
model3.add(MaxPooling2D(pool_size=(2,2)))
model3.add(BatchNormalization())
model3.add(layers.Dropout(0.2))

#To feed this into our model, we need to flatten
model3.add(Flatten())

#Fully connected layer
# 1 Hidden Layer
model3.add(Dense(256, activation = 'relu'))
model3.add(BatchNormalization())
model2.add(layers.Dropout(0.2))    #Added Drop Out

#Output Layer
model3.add(Dense(1, activation = 'sigmoid'))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_4 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_5 (MaxPooling  (None, 62, 62, 128)      0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 62, 62, 128)      512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 62, 62, 128)       0
#
#  flatten_2 (Flatten)         (None, 492032)            0
#
#  dense_4 (Dense)             (None, 256)               125960448
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 126,038,145
# Trainable params: 126,037,249
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
model3.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
# Let's train the model by fitting it
h3 = model3.fit(train, validation_data = val, epochs = 10, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/10
# 4376/4376 [==============================] - 1642s 375ms/step - loss: 0.2690 - acc: 0.8845 - precision_2: 0.8773 - recall_2: 0.8939 - auc_2: 0.9555 - false_negatives_2: 7428.0000 - false_positives_2: 8750.0000 - true_negatives_2: 61258.0000 - true_positives_2: 62574.0000 - val_loss: 0.3488 - val_acc: 0.8546 - val_precision_2: 0.9403 - val_recall_2: 0.7585 - val_auc_2: 0.9548 - val_false_negatives_2: 4781.0000 - val_false_positives_2: 954.0000 - val_true_negatives_2: 18701.0000 - val_true_positives_2: 15019.0000 - lr: 0.0010
# Epoch 2/10
# 4376/4376 [==============================] - 1638s 374ms/step - loss: 0.1496 - acc: 0.9394 - precision_2: 0.9348 - recall_2: 0.9447 - auc_2: 0.9861 - false_negatives_2: 3868.0000 - false_positives_2: 4610.0000 - true_negatives_2: 65398.0000 - true_positives_2: 66134.0000 - val_loss: 0.2667 - val_acc: 0.8884 - val_precision_2: 0.8841 - val_recall_2: 0.8949 - val_auc_2: 0.9589 - val_false_negatives_2: 2081.0000 - val_false_positives_2: 2323.0000 - val_true_negatives_2: 17332.0000 - val_true_positives_2: 17719.0000 - lr: 0.0010
# Epoch 3/10
# 4376/4376 [==============================] - 1645s 376ms/step - loss: 0.0919 - acc: 0.9641 - precision_2: 0.9619 - recall_2: 0.9665 - auc_2: 0.9945 - false_negatives_2: 2344.0000 - false_positives_2: 2678.0000 - true_negatives_2: 67330.0000 - true_positives_2: 67658.0000 - val_loss: 0.6337 - val_acc: 0.7980 - val_precision_2: 0.7226 - val_recall_2: 0.9698 - val_auc_2: 0.9297 - val_false_negatives_2: 597.0000 - val_false_positives_2: 7373.0000 - val_true_negatives_2: 12282.0000 - val_true_positives_2: 19203.0000 - lr: 0.0010
# Epoch 4/10
# 4376/4376 [==============================] - 1634s 374ms/step - loss: 0.0690 - acc: 0.9738 - precision_2: 0.9725 - recall_2: 0.9752 - auc_2: 0.9967 - false_negatives_2: 1738.0000 - false_positives_2: 1927.0000 - true_negatives_2: 68081.0000 - true_positives_2: 68264.0000 - val_loss: 0.2429 - val_acc: 0.9111 - val_precision_2: 0.8790 - val_recall_2: 0.9541 - val_auc_2: 0.9744 - val_false_negatives_2: 908.0000 - val_false_positives_2: 2600.0000 - val_true_negatives_2: 17055.0000 - val_true_positives_2: 18892.0000 - lr: 0.0010
# Epoch 5/10
# 4376/4376 [==============================] - 1633s 373ms/step - loss: 0.0620 - acc: 0.9765 - precision_2: 0.9758 - recall_2: 0.9773 - auc_2: 0.9973 - false_negatives_2: 1586.0000 - false_positives_2: 1700.0000 - true_negatives_2: 68308.0000 - true_positives_2: 68416.0000 - val_loss: 0.3083 - val_acc: 0.9086 - val_precision_2: 0.9017 - val_recall_2: 0.9178 - val_auc_2: 0.9640 - val_false_negatives_2: 1627.0000 - val_false_positives_2: 1981.0000 - val_true_negatives_2: 17674.0000 - val_true_positives_2: 18173.0000 - lr: 0.0010
# Epoch 6/10
# 4376/4376 [==============================] - 1641s 375ms/step - loss: 0.0421 - acc: 0.9848 - precision_2: 0.9842 - recall_2: 0.9855 - auc_2: 0.9985 - false_negatives_2: 1014.0000 - false_positives_2: 1108.0000 - true_negatives_2: 68900.0000 - true_positives_2: 68988.0000 - val_loss: 0.3787 - val_acc: 0.8773 - val_precision_2: 0.8483 - val_recall_2: 0.9202 - val_auc_2: 0.9465 - val_false_negatives_2: 1581.0000 - val_false_positives_2: 3259.0000 - val_true_negatives_2: 16396.0000 - val_true_positives_2: 18219.0000 - lr: 0.0010
# Epoch 7/10
# 4376/4376 [==============================] - 1642s 375ms/step - loss: 0.0372 - acc: 0.9869 - precision_2: 0.9863 - recall_2: 0.9875 - auc_2: 0.9987 - false_negatives_2: 873.0000 - false_positives_2: 957.0000 - true_negatives_2: 69051.0000 - true_positives_2: 69129.0000 - val_loss: 0.4873 - val_acc: 0.7929 - val_precision_2: 0.8406 - val_recall_2: 0.7246 - val_auc_2: 0.8862 - val_false_negatives_2: 5452.0000 - val_false_positives_2: 2720.0000 - val_true_negatives_2: 16935.0000 - val_true_positives_2: 14348.0000 - lr: 0.0010
# Epoch 7: early stopping

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h3.history['loss'][-1]}\n\
Val Loss: {h3.history['val_loss'][-1]}\n\
Train Acc:{h3.history['acc'][-1]}\n\
Val Acc:{h3.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.03715172037482262
# Val Loss: 0.4872954785823822
# Train Acc:0.9869294762611389
# Val Acc:0.7928779721260071

# %% [markdown]
# <u>Model 3 Performance</u>
# * The Training and Tetsting Loss has both decreased compared to model 1. There still seems to be some overfitting as the test loss (0.457) is significantly greater than the train loss (0.027).
# * The Training accuracy (99.1%) is higher than the test accuracy (91.0%). Both values have increased compared to model 1.
#
# Further methods will need to be explored to help with overfitting.

# %%
# Append last epoch scores to model_eval.csv 
config.model_scores_to_csv(model3, h3, 'model_3')

# %%
config.graph_me(h3, ['acc'])

plt.savefig('model3_r.png')

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h3.history['loss'],label='Train Loss')
plt.plot(h3.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 3 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h3.history['acc'],label='Train ccuracy')
plt.plot(h3.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 3 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model3.png')

# Display the plot
plt.show();

# %%
# serialize model to JSON
anna_model3_json = model3.to_json()
with open("anna_model3.json", "w") as json_file:
    json_file.write(anna_model3_json)

# serialize weights to HDF5
model3.save_weights("anna_model3.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model3.save('anna_model3_complete.h5')

# %% [markdown]
# # Model 4 - Larger Dropout

# %%
model4 = Sequential()

model4.add(layers.Input(shape = (h,w,3)))
#normalize pixel and preprocess images in network
model4.add(layers.Rescaling(1./255))


#First Convolution layer
model4.add(Conv2D(64, (3,3), activation = 'relu'))

#MaxPooling
model4.add(MaxPooling2D(pool_size = (2,2)))
model4.add(BatchNormalization())

# 2nd Convolution layer
model4.add(Conv2D(128, (3,3), activation = 'relu'))
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(BatchNormalization())
model4.add(layers.Dropout(0.3)) #Larger Dropout

#To feed this into our model, we need to flatten
model4.add(Flatten())

#Fully connected layer
# 1 Hidden Layer
model4.add(Dense(256, activation = 'relu'))
model4.add(BatchNormalization())
#model4.add(layers.Dropout(0.3))     #Removed Dropout since it did worse in model3

#Output Layer
model4.add(Dense(1, activation = 'sigmoid'))

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_6 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_7 (MaxPooling  (None, 62, 62, 128)      0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 62, 62, 128)      512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 62, 62, 128)       0
#
#  flatten_3 (Flatten)         (None, 492032)            0
#
#  dense_6 (Dense)             (None, 256)               125960448
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 126,038,145
# Trainable params: 126,037,249
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
model4.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
# Let's train the model by fitting it
h4 = model4.fit(train, validation_data = val, epochs = 10, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/10
# 2023-05-20 16:06:11.567803: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 4376/4376 [==============================] - 1630s 372ms/step - loss: 0.3221 - acc: 0.8572 - precision_1: 0.8495 - recall_1: 0.8682 - auc_1: 0.9365 - false_negatives_1: 9228.0000 - false_positives_1: 10768.0000 - true_negatives_1: 59240.0000 - true_positives_1: 60774.0000 - val_loss: 0.3338 - val_acc: 0.8560 - val_precision_1: 0.8989 - val_recall_1: 0.8033 - val_auc_1: 0.9407 - val_false_negatives_1: 3894.0000 - val_false_positives_1: 1788.0000 - val_true_negatives_1: 17867.0000 - val_true_positives_1: 15906.0000 - lr: 0.0010
# Epoch 2/10
# 4376/4376 [==============================] - 1627s 372ms/step - loss: 0.1549 - acc: 0.9374 - precision_1: 0.9332 - recall_1: 0.9422 - auc_1: 0.9851 - false_negatives_1: 4043.0000 - false_positives_1: 4718.0000 - true_negatives_1: 65290.0000 - true_positives_1: 65959.0000 - val_loss: 0.2419 - val_acc: 0.8985 - val_precision_1: 0.8556 - val_recall_1: 0.9598 - val_auc_1: 0.9730 - val_false_negatives_1: 796.0000 - val_false_positives_1: 3208.0000 - val_true_negatives_1: 16447.0000 - val_true_positives_1: 19004.0000 - lr: 0.0010
# Epoch 3/10
# 4376/4376 [==============================] - 1628s 372ms/step - loss: 0.0882 - acc: 0.9659 - precision_1: 0.9635 - recall_1: 0.9685 - auc_1: 0.9949 - false_negatives_1: 2202.0000 - false_positives_1: 2571.0000 - true_negatives_1: 67437.0000 - true_positives_1: 67800.0000 - val_loss: 0.2637 - val_acc: 0.9131 - val_precision_1: 0.8921 - val_recall_1: 0.9406 - val_auc_1: 0.9712 - val_false_negatives_1: 1177.0000 - val_false_positives_1: 2253.0000 - val_true_negatives_1: 17402.0000 - val_true_positives_1: 18623.0000 - lr: 0.0010
# Epoch 4/10
# 4376/4376 [==============================] - 1631s 373ms/step - loss: 0.0702 - acc: 0.9737 - precision_1: 0.9727 - recall_1: 0.9748 - auc_1: 0.9966 - false_negatives_1: 1765.0000 - false_positives_1: 1914.0000 - true_negatives_1: 68094.0000 - true_positives_1: 68237.0000 - val_loss: 0.2239 - val_acc: 0.9189 - val_precision_1: 0.9246 - val_recall_1: 0.9127 - val_auc_1: 0.9738 - val_false_negatives_1: 1728.0000 - val_false_positives_1: 1473.0000 - val_true_negatives_1: 18182.0000 - val_true_positives_1: 18072.0000 - lr: 0.0010
# Epoch 5/10
# 4376/4376 [==============================] - 1629s 372ms/step - loss: 0.0516 - acc: 0.9812 - precision_1: 0.9807 - recall_1: 0.9818 - auc_1: 0.9979 - false_negatives_1: 1276.0000 - false_positives_1: 1356.0000 - true_negatives_1: 68652.0000 - true_positives_1: 68726.0000 - val_loss: 0.2587 - val_acc: 0.9140 - val_precision_1: 0.8972 - val_recall_1: 0.9358 - val_auc_1: 0.9718 - val_false_negatives_1: 1271.0000 - val_false_positives_1: 2122.0000 - val_true_negatives_1: 17533.0000 - val_true_positives_1: 18529.0000 - lr: 0.0010
# Epoch 6/10
# 4376/4376 [==============================] - 1631s 373ms/step - loss: 0.0514 - acc: 0.9813 - precision_1: 0.9807 - recall_1: 0.9818 - auc_1: 0.9979 - false_negatives_1: 1276.0000 - false_positives_1: 1349.0000 - true_negatives_1: 68659.0000 - true_positives_1: 68726.0000 - val_loss: 0.3567 - val_acc: 0.9048 - val_precision_1: 0.8702 - val_recall_1: 0.9523 - val_auc_1: 0.9641 - val_false_negatives_1: 944.0000 - val_false_positives_1: 2812.0000 - val_true_negatives_1: 16843.0000 - val_true_positives_1: 18856.0000 - lr: 0.0010
# Epoch 7/10
# 4376/4376 [==============================] - 1628s 372ms/step - loss: 0.0363 - acc: 0.9868 - precision_1: 0.9863 - recall_1: 0.9873 - auc_1: 0.9988 - false_negatives_1: 889.0000 - false_positives_1: 960.0000 - true_negatives_1: 69048.0000 - true_positives_1: 69113.0000 - val_loss: 0.2601 - val_acc: 0.9181 - val_precision_1: 0.9142 - val_recall_1: 0.9236 - val_auc_1: 0.9700 - val_false_negatives_1: 1513.0000 - val_false_positives_1: 1717.0000 - val_true_negatives_1: 17938.0000 - val_true_positives_1: 18287.0000 - lr: 0.0010
# Epoch 7: early stopping

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h4.history['loss'][-1]}\n\
Val Loss: {h4.history['val_loss'][-1]}\n\
Train Acc: {h4.history['acc'][-1]}\n\
Val Acc: {h4.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.036311160773038864
# Val Loss: 0.26011666655540466
# Train Acc: 0.9867938160896301
# Val Acc: 0.9181346297264099

# %%
h4.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'precision_1', 'recall_1', 'auc_1', 'false_negatives_1', 'false_positives_1', 'true_negatives_1', 'true_positives_1', 'val_loss', 'val_acc', 'val_precision_1', 'val_recall_1', 'val_auc_1', 'val_false_negatives_1', 'val_false_positives_1', 'val_true_negatives_1', 'val_true_positives_1', 'lr'])

# %%
list(h4.history.values())
# Out:
# [[0.32206305861473083,
#   0.15492114424705505,
#   0.08820991963148117,
#   0.07015368342399597,
#   0.05163630470633507,
#   0.05141066759824753,
#   0.036311160773038864],
#  [0.8571816086769104,
#   0.9374259114265442,
#   0.9659096002578735,
#   0.973723292350769,
#   0.9812013506889343,
#   0.9812513589859009,
#   0.9867938160896301],
#  [0.8494870066642761,
#   0.9332455992698669,
#   0.9634650349617004,
#   0.9727159738540649,
#   0.9806512594223022,
#   0.9807491898536682,
#   0.9863000512123108],
#  [0.868175208568573,
#   0.9422444701194763,
#   0.9685437679290771,
#   0.9747864007949829,
#   0.9817719459533691,
#   0.9817719459533691,
#   0.9873003363609314],
#  [0.9364930987358093,
#   0.9850568771362305,
#   0.9948592782020569,
#   0.9965512752532959,
#   0.9979119896888733,
#   0.9978758096694946,
#   0.998825192451477],
#  [9228.0, 4043.0, 2202.0, 1765.0, 1276.0, 1276.0, 889.0],
#  [10768.0, 4718.0, 2571.0, 1914.0, 1356.0, 1349.0, 960.0],
#  [59240.0, 65290.0, 67437.0, 68094.0, 68652.0, 68659.0, 69048.0],
#  [60774.0, 65959.0, 67800.0, 68237.0, 68726.0, 68726.0, 69113.0],
#  [0.33382272720336914,
#   0.2419411540031433,
#   0.26365917921066284,
#   0.22393104434013367,
#   0.2587421238422394,
#   0.35670962929725647,
#   0.26011666655540466],
#  [0.8559878468513489,
#   0.8985173106193542,
#   0.9130655527114868,
#   0.9188696146011353,
#   0.914003312587738,
#   0.9048029780387878,
#   0.9181346297264099],
#  [0.8989487886428833,
#   0.8555735945701599,
#   0.8920770287513733,
#   0.9246354699134827,
#   0.8972446918487549,
#   0.8702234029769897,
#   0.9141671657562256],
#  [0.8033333420753479,
#   0.9597980380058289,
#   0.9405555725097656,
#   0.9127272963523865,
#   0.9358081221580505,
#   0.9523232579231262,
#   0.9235858917236328],
#  [0.9406812191009521,
#   0.972984790802002,
#   0.9712122082710266,
#   0.973789632320404,
#   0.9718073606491089,
#   0.9640594124794006,
#   0.9699560403823853],
#  [3894.0, 796.0, 1177.0, 1728.0, 1271.0, 944.0, 1513.0],
#  [1788.0, 3208.0, 2253.0, 1473.0, 2122.0, 2812.0, 1717.0],
#  [17867.0, 16447.0, 17402.0, 18182.0, 17533.0, 16843.0, 17938.0],
#  [15906.0, 19004.0, 18623.0, 18072.0, 18529.0, 18856.0, 18287.0],
#  [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]]

# %%
# Append last epoch scores to model_eval.csv 
model_scores_to_csv(model4, h4, 'model_4')

# %%
config.graph_me(h4, ['acc'])

plt.savefig('model4_r.png')

plt.show();

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h4.history['loss'],label='Train Loss')
plt.plot(h4.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 4 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h4.history['acc'],label='Train Accuracy')
plt.plot(h4.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 4 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model4.png')

# Display the plot
plt.show();

# %%
# serialize model to JSON
anna_model4_json = model4.to_json()
with open("anna_model4.json", "w") as json_file:
    json_file.write(anna_model4_json)

# serialize weights to HDF5
model4.save_weights("anna_model4.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model4.save('anna_model4_complete.h5')

# %% [markdown]
# # Model 5: L2 Regularization

# %%
from tensorflow.keras.regularizers import l2

# %%
model5 = Sequential()

model5.add(layers.Input(shape = (h,w,3)))
#normalize pixel and preprocess images in network
model5.add(layers.Rescaling(1./255))


#First Convolution layer
model5.add(Conv2D(64, (3,3), activation = 'relu'))

#MaxPooling
model5.add(MaxPooling2D(pool_size = (2,2)))
model5.add(BatchNormalization())

# 2nd Convolution layer
model5.add(Conv2D(128, (3,3), activation = 'relu', kernel_regularizer=l2(0.001)))
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(BatchNormalization())
model5.add(layers.Dropout(0.3)) #Larger Dropout

#To feed this into our model, we need to flatten
model5.add(Flatten())

#Fully connected layer
# 1 Hidden Layer
model5.add(Dense(256, activation = 'relu'))
model5.add(BatchNormalization())

#Output Layer
model5.add(Dense(1, activation = 'sigmoid'))

model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_8 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_8 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  batch_normalization_9 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_9 (MaxPooling  (None, 62, 62, 128)      0
#  2D)
#
#  batch_normalization_10 (Bat  (None, 62, 62, 128)      512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 62, 62, 128)       0
#
#  flatten_4 (Flatten)         (None, 492032)            0
#
#  dense_8 (Dense)             (None, 256)               125960448
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 126,038,145
# Trainable params: 126,037,249
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
model5.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
h5 = model5.fit(train, validation_data = val, epochs = 10, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/10
# 4376/4376 [==============================] - 1654s 378ms/step - loss: 0.3716 - acc: 0.8457 - precision_2: 0.8372 - recall_2: 0.8583 - auc_2: 0.9281 - false_negatives_2: 9916.0000 - false_positives_2: 11687.0000 - true_negatives_2: 58321.0000 - true_positives_2: 60086.0000 - val_loss: 0.4218 - val_acc: 0.8334 - val_precision_2: 0.8480 - val_recall_2: 0.8140 - val_auc_2: 0.9179 - val_false_negatives_2: 3683.0000 - val_false_positives_2: 2889.0000 - val_true_negatives_2: 16766.0000 - val_true_positives_2: 16117.0000 - lr: 0.0010
# Epoch 2/10
# 4376/4376 [==============================] - 1658s 379ms/step - loss: 0.1997 - acc: 0.9303 - precision_2: 0.9259 - recall_2: 0.9354 - auc_2: 0.9820 - false_negatives_2: 4521.0000 - false_positives_2: 5243.0000 - true_negatives_2: 64765.0000 - true_positives_2: 65481.0000 - val_loss: 0.2938 - val_acc: 0.8896 - val_precision_2: 0.8515 - val_recall_2: 0.9447 - val_auc_2: 0.9645 - val_false_negatives_2: 1095.0000 - val_false_positives_2: 3262.0000 - val_true_negatives_2: 16393.0000 - val_true_positives_2: 18705.0000 - lr: 0.0010
# Epoch 3/10
# 4376/4376 [==============================] - 1659s 379ms/step - loss: 0.1441 - acc: 0.9525 - precision_2: 0.9496 - recall_2: 0.9556 - auc_2: 0.9911 - false_negatives_2: 3109.0000 - false_positives_2: 3548.0000 - true_negatives_2: 66460.0000 - true_positives_2: 66893.0000 - val_loss: 0.4087 - val_acc: 0.8490 - val_precision_2: 0.8685 - val_recall_2: 0.8238 - val_auc_2: 0.9256 - val_false_negatives_2: 3489.0000 - val_false_positives_2: 2469.0000 - val_true_negatives_2: 17186.0000 - val_true_positives_2: 16311.0000 - lr: 0.0010
# Epoch 4/10
# 4376/4376 [==============================] - 1660s 379ms/step - loss: 0.1476 - acc: 0.9559 - precision_2: 0.9537 - recall_2: 0.9584 - auc_2: 0.9920 - false_negatives_2: 2913.0000 - false_positives_2: 3259.0000 - true_negatives_2: 66749.0000 - true_positives_2: 67089.0000 - val_loss: 0.2932 - val_acc: 0.9026 - val_precision_2: 0.8817 - val_recall_2: 0.9308 - val_auc_2: 0.9663 - val_false_negatives_2: 1370.0000 - val_false_positives_2: 2473.0000 - val_true_negatives_2: 17182.0000 - val_true_positives_2: 18430.0000 - lr: 0.0010
# Epoch 5/10
# 4376/4376 [==============================] - 1658s 379ms/step - loss: 0.1672 - acc: 0.9511 - precision_2: 0.9487 - recall_2: 0.9538 - auc_2: 0.9902 - false_negatives_2: 3232.0000 - false_positives_2: 3614.0000 - true_negatives_2: 66394.0000 - true_positives_2: 66770.0000 - val_loss: 0.3209 - val_acc: 0.9007 - val_precision_2: 0.8678 - val_recall_2: 0.9464 - val_auc_2: 0.9659 - val_false_negatives_2: 1061.0000 - val_false_positives_2: 2855.0000 - val_true_negatives_2: 16800.0000 - val_true_positives_2: 18739.0000 - lr: 0.0010
# Epoch 6/10
# 4376/4376 [==============================] - 1658s 379ms/step - loss: 0.0989 - acc: 0.9736 - precision_2: 0.9721 - recall_2: 0.9752 - auc_2: 0.9967 - false_negatives_2: 1734.0000 - false_positives_2: 1957.0000 - true_negatives_2: 68051.0000 - true_positives_2: 68268.0000 - val_loss: 0.3342 - val_acc: 0.8873 - val_precision_2: 0.9129 - val_recall_2: 0.8573 - val_auc_2: 0.9569 - val_false_negatives_2: 2825.0000 - val_false_positives_2: 1620.0000 - val_true_negatives_2: 18035.0000 - val_true_positives_2: 16975.0000 - lr: 0.0010
# Epoch 7/10
# 4376/4376 [==============================] - 1658s 379ms/step - loss: 0.0928 - acc: 0.9743 - precision_2: 0.9730 - recall_2: 0.9756 - auc_2: 0.9967 - false_negatives_2: 1705.0000 - false_positives_2: 1894.0000 - true_negatives_2: 68114.0000 - true_positives_2: 68297.0000 - val_loss: 0.4188 - val_acc: 0.8784 - val_precision_2: 0.8278 - val_recall_2: 0.9566 - val_auc_2: 0.9578 - val_false_negatives_2: 859.0000 - val_false_positives_2: 3939.0000 - val_true_negatives_2: 15716.0000 - val_true_positives_2: 18941.0000 - lr: 0.0010
# Epoch 7: early stopping

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h5.history['loss'][-1]}\n\
Val Loss: {h5.history['val_loss'][-1]}\n\
Train Acc: {h5.history['acc'][-1]}\n\
Val Acc: {h5.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.09276613593101501
# Val Loss: 0.4187655448913574
# Train Acc: 0.9742946624755859
# Val Acc: 0.8783931136131287

# %%
# Append last epoch scores to model_eval.csv 
model_scores_to_csv(model5, h5, 'model_5')

# %%
config.graph_me(h5, ['acc'])

plt.savefig('model5_r.png')

plt.show();

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h5.history['loss'],label='Train Loss')
plt.plot(h5.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 5 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h5.history['acc'],label='Train Accuracy')
plt.plot(h5.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 5 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model5.png')

# Display the plot
plt.show();

# %%
# serialize model to JSON
anna_model6_json = model6.to_json()
with open("anna_model6.json", "w") as json_file:
    json_file.write(anna_model6_json)

# serialize weights to HDF5
model6.save_weights("anna_model6.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model6.save('anna_model6_complete.h5')

# %% [markdown]
# # C. Transfer Learning

# %% [markdown]
# ## Model 6: EfficientNetV2L

# %%
model6 = Sequential()

effnet_V2L_pretrained = EfficientNetV2L(
    weights='imagenet',   
    input_shape=(h,w,3), 
    include_top=False,
    include_preprocessing=True     #Efficientnet_2L expects [-1, 1] range, if set to False
)

effnet_V2L_pretrained.trainable = False

model6.add(effnet_V2L_pretrained)

model6.add(Flatten())

model6.add(Dense(256, activation='relu'))
model6.add(BatchNormalization())
model6.add(Dropout(0.3))

model6.add(Dense(units = 1, activation='sigmoid'))
model6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-l (Functiona  (None, 8, 8, 1280)       117746848
#  l)
#
#  flatten_5 (Flatten)         (None, 81920)             0
#
#  dense_10 (Dense)            (None, 256)               20971776
#
#  batch_normalization_12 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 138,719,905
# Trainable params: 20,972,545
# Non-trainable params: 117,747,360
# _________________________________________________________________

# %%
# Compile
model6.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
h6 = model6.fit(train, validation_data = val, epochs = 10, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/10
# 4376/4376 [==============================] - 2132s 485ms/step - loss: 0.3709 - acc: 0.8325 - precision_3: 0.8253 - recall_3: 0.8435 - auc_3: 0.9142 - false_negatives_3: 10952.0000 - false_positives_3: 12503.0000 - true_negatives_3: 57505.0000 - true_positives_3: 59050.0000 - val_loss: 0.3300 - val_acc: 0.8525 - val_precision_3: 0.8829 - val_recall_3: 0.8141 - val_auc_3: 0.9368 - val_false_negatives_3: 3681.0000 - val_false_positives_3: 2138.0000 - val_true_negatives_3: 17517.0000 - val_true_positives_3: 16119.0000 - lr: 0.0010
# Epoch 2/10
# 4376/4376 [==============================] - 2073s 474ms/step - loss: 0.2792 - acc: 0.8789 - precision_3: 0.8732 - recall_3: 0.8864 - auc_3: 0.9520 - false_negatives_3: 7953.0000 - false_positives_3: 9009.0000 - true_negatives_3: 60999.0000 - true_positives_3: 62049.0000 - val_loss: 0.3138 - val_acc: 0.8622 - val_precision_3: 0.8906 - val_recall_3: 0.8271 - val_auc_3: 0.9432 - val_false_negatives_3: 3423.0000 - val_false_positives_3: 2012.0000 - val_true_negatives_3: 17643.0000 - val_true_positives_3: 16377.0000 - lr: 0.0010
# Epoch 3/10
# 4376/4376 [==============================] - 2076s 474ms/step - loss: 0.2338 - acc: 0.9013 - precision_3: 0.8963 - recall_3: 0.9076 - auc_3: 0.9665 - false_negatives_3: 6471.0000 - false_positives_3: 7350.0000 - true_negatives_3: 62658.0000 - true_positives_3: 63531.0000 - val_loss: 0.2809 - val_acc: 0.8780 - val_precision_3: 0.8856 - val_recall_3: 0.8691 - val_auc_3: 0.9522 - val_false_negatives_3: 2591.0000 - val_false_positives_3: 2222.0000 - val_true_negatives_3: 17433.0000 - val_true_positives_3: 17209.0000 - lr: 0.0010
# Epoch 4/10
# 4376/4376 [==============================] - 2081s 476ms/step - loss: 0.1992 - acc: 0.9178 - precision_3: 0.9129 - recall_3: 0.9238 - auc_3: 0.9756 - false_negatives_3: 5336.0000 - false_positives_3: 6171.0000 - true_negatives_3: 63837.0000 - true_positives_3: 64666.0000 - val_loss: 0.2706 - val_acc: 0.8861 - val_precision_3: 0.8757 - val_recall_3: 0.9009 - val_auc_3: 0.9561 - val_false_negatives_3: 1963.0000 - val_false_positives_3: 2532.0000 - val_true_negatives_3: 17123.0000 - val_true_positives_3: 17837.0000 - lr: 0.0010
# Epoch 5/10
# 4376/4376 [==============================] - 2082s 476ms/step - loss: 0.1729 - acc: 0.9299 - precision_3: 0.9260 - recall_3: 0.9345 - auc_3: 0.9815 - false_negatives_3: 4588.0000 - false_positives_3: 5228.0000 - true_negatives_3: 64780.0000 - true_positives_3: 65414.0000 - val_loss: 0.2794 - val_acc: 0.8866 - val_precision_3: 0.8871 - val_recall_3: 0.8870 - val_auc_3: 0.9544 - val_false_negatives_3: 2237.0000 - val_false_positives_3: 2236.0000 - val_true_negatives_3: 17419.0000 - val_true_positives_3: 17563.0000 - lr: 0.0010
# Epoch 6/10
# 4376/4376 [==============================] - 2084s 476ms/step - loss: 0.1520 - acc: 0.9394 - precision_3: 0.9361 - recall_3: 0.9432 - auc_3: 0.9856 - false_negatives_3: 3978.0000 - false_positives_3: 4508.0000 - true_negatives_3: 65500.0000 - true_positives_3: 66024.0000 - val_loss: 0.2772 - val_acc: 0.8908 - val_precision_3: 0.8910 - val_recall_3: 0.8916 - val_auc_3: 0.9572 - val_false_negatives_3: 2147.0000 - val_false_positives_3: 2160.0000 - val_true_negatives_3: 17495.0000 - val_true_positives_3: 17653.0000 - lr: 0.0010
# Epoch 7/10
# 4376/4376 [==============================] - 2086s 477ms/step - loss: 0.1355 - acc: 0.9465 - precision_3: 0.9437 - recall_3: 0.9495 - auc_3: 0.9884 - false_negatives_3: 3532.0000 - false_positives_3: 3962.0000 - true_negatives_3: 66046.0000 - true_positives_3: 66470.0000 - val_loss: 0.2864 - val_acc: 0.8912 - val_precision_3: 0.8875 - val_recall_3: 0.8969 - val_auc_3: 0.9564 - val_false_negatives_3: 2042.0000 - val_false_positives_3: 2252.0000 - val_true_negatives_3: 17403.0000 - val_true_positives_3: 17758.0000 - lr: 0.0010
# Epoch 7: early stopping

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h6.history['loss'][-1]}\n\
Val Loss: {h6.history['val_loss'][-1]}\n\
Train Acc: {h6.history['acc'][-1]}\n\
Val Acc: {h6.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.13548427820205688
# Val Loss: 0.2863996624946594
# Train Acc: 0.9464752674102783
# Val Acc: 0.891167163848877

# %%
# Append last epoch scores to model_eval.csv 
model_scores_to_csv(model6, h6, 'model_6')

# %%
config.graph_me(h6, ['acc'])

plt.savefig('model6_r.png')

plt.show();

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h6.history['loss'],label='Train Loss')
plt.plot(h6.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 6 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h6.history['acc'],label='Train Accuracy')
plt.plot(h6.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 6 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model6.png')

# Display the plot
plt.show();

# %%
# serialize model to JSON
anna_model6_json = model6.to_json()
with open("anna_model6.json", "w") as json_file:
    json_file.write(anna_model6_json)

# serialize weights to HDF5
model6.save_weights("anna_model6.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model6.save('anna_model6_complete.h5')

# %% [markdown]
# # Data Augmentation

# %%
# Imports
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental.preprocessing import (RandomFlip, RandomRotation, 
                                                                RandomZoom, RandomContrast)

# %%
# Test on single image

train_path = '../../../Dataset/Train/'

img = img_to_array(load_img(train_path + 'Fake/Fake_9.jpg'))

w = img.shape[0]
h = img.shape[1]

exp_img = np.expand_dims(img, axis=0)

# %%
# Setting up Augmentation model

data_aug = Sequential([
    RandomFlip('horizontal', input_shape=(h,w,3)),
    RandomRotation(0.3),
    RandomZoom(0.3),
    RandomContrast(0.3)
])

# %%
# Test on single image
data_aug(exp_img)
# Out:
# <tf.Tensor: shape=(1, 256, 256, 3), dtype=float32, numpy=
# array([[[[196.12984   , 165.4487    , 144.61728   ],
#          [196.73056   , 163.87068   , 141.74945   ],
#          [196.88684   , 161.8581    , 139.00562   ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [254.61365   , 255.        , 255.        ],
#          [254.79167   , 255.        , 255.        ]],
#
#         [[194.5486    , 164.73442   , 144.43854   ],
#          [196.44452   , 164.07281   , 142.35818   ],
#          [197.75334   , 162.76582   , 140.11298   ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ]],
#
#         [[193.11328   , 163.62352   , 144.09384   ],
#          [196.12502   , 163.48703   , 142.43027   ],
#          [198.57384   , 163.07516   , 140.82861   ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ]],
#
#         ...,
#
#         [[ 33.942436  ,   1.9814224 ,   0.        ],
#          [ 31.908524  ,   0.32691193,   0.        ],
#          [ 28.244888  ,   0.        ,   0.        ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ]],
#
#         [[ 40.278046  ,   4.730194  ,   0.        ],
#          [ 35.848297  ,   1.6241455 ,   0.        ],
#          [ 32.544746  ,   0.        ,   0.        ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ]],
#
#         [[ 40.13408   ,   2.6773148 ,   0.        ],
#          [ 36.626717  ,   0.30940247,   0.        ],
#          [ 35.418617  ,   2.042572  ,   1.0867996 ],
#          ...,
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ],
#          [255.        , 255.        , 255.        ]]]], dtype=float32)>

# %%
# Squeeze to normal image dimension
new_img = np.squeeze(exp_img)
new_img.shape
# Out:
# (256, 256, 3)

# %%
# Show new image
plt.imshow(new_img * 1./255);

# %%
# Finalized function 
new_img_aug = data_augmentation(exp_img)
new_img = np.squeeze(new_img_aug)
plt.imshow(new_img * 1./255);

# %% [markdown]
# # Model 7: EfficientNetV2L with Augmentation

# %%
model7 = Sequential()

effnet_V2L_pretrained = EfficientNetV2L(
    weights='imagenet',   
    input_shape=(h,w,3), 
    include_top=False,
    include_preprocessing=True      #Efficientnet_2L expects [-1, 1] range, if set to False
)

effnet_V2L_pretrained.trainable = False

model7.add(data_aug)
model7.add(effnet_V2L_pretrained)

model7.add(GlobalAveragePooling2D())

model7.add(Dense(256, activation='relu'))
model7.add(BatchNormalization())
model7.add(Dropout(0.3))

model7.add(Dense(units = 1, activation='sigmoid'))
model7.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 256, 256, 3)       0
#
#  efficientnetv2-l (Functiona  (None, 8, 8, 1280)       117746848
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense_12 (Dense)            (None, 256)               327936
#
#  batch_normalization_13 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 118,076,065
# Trainable params: 328,705
# Non-trainable params: 117,747,360
# _________________________________________________________________

# %%
# Compile
model7.compile(
    optimizer='adam',
    loss = 'bce',
    metrics = ['acc', 
                         metrics.Precision(), metrics.Recall(), 
                         metrics.AUC(),
                         metrics.FalseNegatives(), metrics.FalsePositives(),
                         metrics.TrueNegatives(),
                         metrics.TruePositives()]
)

# %%
h7 = model7.fit(train, validation_data = val, epochs = 10, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/10
# 4376/4376 [==============================] - 2174s 493ms/step - loss: 0.5328 - acc: 0.7320 - precision_4: 0.7242 - recall_4: 0.7492 - auc_4: 0.8091 - false_negatives_4: 17556.0000 - false_positives_4: 19971.0000 - true_negatives_4: 50037.0000 - true_positives_4: 52446.0000 - val_loss: 0.4999 - val_acc: 0.7614 - val_precision_4: 0.7886 - val_recall_4: 0.7168 - val_auc_4: 0.8441 - val_false_negatives_4: 5608.0000 - val_false_positives_4: 3804.0000 - val_true_negatives_4: 15851.0000 - val_true_positives_4: 14192.0000 - lr: 0.0010
# Epoch 2/10
# 4376/4376 [==============================] - 2089s 477ms/step - loss: 0.4975 - acc: 0.7530 - precision_4: 0.7434 - recall_4: 0.7726 - auc_4: 0.8352 - false_negatives_4: 15915.0000 - false_positives_4: 18670.0000 - true_negatives_4: 51338.0000 - true_positives_4: 54087.0000 - val_loss: 0.4801 - val_acc: 0.7704 - val_precision_4: 0.8098 - val_recall_4: 0.7090 - val_auc_4: 0.8568 - val_false_negatives_4: 5762.0000 - val_false_positives_4: 3297.0000 - val_true_negatives_4: 16358.0000 - val_true_positives_4: 14038.0000 - lr: 0.0010
# Epoch 3/10
# 4376/4376 [==============================] - 2088s 477ms/step - loss: 0.4860 - acc: 0.7604 - precision_4: 0.7512 - recall_4: 0.7787 - auc_4: 0.8438 - false_negatives_4: 15493.0000 - false_positives_4: 18051.0000 - true_negatives_4: 51957.0000 - true_positives_4: 54509.0000 - val_loss: 0.4651 - val_acc: 0.7823 - val_precision_4: 0.8134 - val_recall_4: 0.7346 - val_auc_4: 0.8662 - val_false_negatives_4: 5254.0000 - val_false_positives_4: 3337.0000 - val_true_negatives_4: 16318.0000 - val_true_positives_4: 14546.0000 - lr: 0.0010
# Epoch 4/10
# 4376/4376 [==============================] - 2146s 490ms/step - loss: 0.4773 - acc: 0.7667 - precision_4: 0.7571 - recall_4: 0.7851 - auc_4: 0.8504 - false_negatives_4: 15043.0000 - false_positives_4: 17628.0000 - true_negatives_4: 52380.0000 - true_positives_4: 54959.0000 - val_loss: 0.4886 - val_acc: 0.7717 - val_precision_4: 0.8200 - val_recall_4: 0.6985 - val_auc_4: 0.8587 - val_false_negatives_4: 5970.0000 - val_false_positives_4: 3036.0000 - val_true_negatives_4: 16619.0000 - val_true_positives_4: 13830.0000 - lr: 0.0010
# Epoch 5/10
# 4376/4376 [==============================] - 2212s 505ms/step - loss: 0.4682 - acc: 0.7715 - precision_4: 0.7623 - recall_4: 0.7891 - auc_4: 0.8567 - false_negatives_4: 14763.0000 - false_positives_4: 17227.0000 - true_negatives_4: 52781.0000 - true_positives_4: 55239.0000 - val_loss: 0.4875 - val_acc: 0.7755 - val_precision_4: 0.8285 - val_recall_4: 0.6969 - val_auc_4: 0.8636 - val_false_negatives_4: 6002.0000 - val_false_positives_4: 2856.0000 - val_true_negatives_4: 16799.0000 - val_true_positives_4: 13798.0000 - lr: 0.0010
# Epoch 6/10
# 4376/4376 [==============================] - 2172s 496ms/step - loss: 0.4669 - acc: 0.7735 - precision_4: 0.7646 - recall_4: 0.7903 - auc_4: 0.8574 - false_negatives_4: 14676.0000 - false_positives_4: 17031.0000 - true_negatives_4: 52977.0000 - true_positives_4: 55326.0000 - val_loss: 0.4741 - val_acc: 0.7795 - val_precision_4: 0.8223 - val_recall_4: 0.7152 - val_auc_4: 0.8658 - val_false_negatives_4: 5640.0000 - val_false_positives_4: 3059.0000 - val_true_negatives_4: 16596.0000 - val_true_positives_4: 14160.0000 - lr: 0.0010
# Epoch 6: early stopping

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h7.history['loss'][-1]}\n\
Val Loss: {h7.history['val_loss'][-1]}\n\
Train Acc: {h7.history['acc'][-1]}\n\
Val Acc: {h7.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.466923326253891
# Val Loss: 0.4741072356700897
# Train Acc: 0.7735375761985779
# Val Acc: 0.7795209884643555

# %%
# Append last epoch scores to model_eval.csv 
model_scores_to_csv(model7, h7, 'model_7')

# %%
h8 = model7.fit(train, validation_data = val, epochs = 5, callbacks = [reduce_lr, es])
# Out:
# Epoch 1/5
# 4376/4376 [==============================] - 2154s 492ms/step - loss: 0.4525 - acc: 0.7831 - precision_4: 0.7743 - recall_4: 0.7989 - auc_4: 0.8672 - false_negatives_4: 14075.0000 - false_positives_4: 16300.0000 - true_negatives_4: 53708.0000 - true_positives_4: 55927.0000 - val_loss: 0.4764 - val_acc: 0.7817 - val_precision_4: 0.8407 - val_recall_4: 0.6971 - val_auc_4: 0.8723 - val_false_negatives_4: 5997.0000 - val_false_positives_4: 2616.0000 - val_true_negatives_4: 17039.0000 - val_true_positives_4: 13803.0000 - lr: 5.0000e-04
# Epoch 2/5
# 4376/4376 [==============================] - 2151s 492ms/step - loss: 0.4499 - acc: 0.7843 - precision_4: 0.7752 - recall_4: 0.8009 - auc_4: 0.8687 - false_negatives_4: 13938.0000 - false_positives_4: 16259.0000 - true_negatives_4: 53749.0000 - true_positives_4: 56064.0000 - val_loss: 0.4737 - val_acc: 0.7844 - val_precision_4: 0.8411 - val_recall_4: 0.7032 - val_auc_4: 0.8741 - val_false_negatives_4: 5877.0000 - val_false_positives_4: 2630.0000 - val_true_negatives_4: 17025.0000 - val_true_positives_4: 13923.0000 - lr: 5.0000e-04
# Epoch 3/5
# 4376/4376 [==============================] - 2162s 494ms/step - loss: 0.4465 - acc: 0.7869 - precision_4: 0.7774 - recall_4: 0.8040 - auc_4: 0.8710 - false_negatives_4: 13718.0000 - false_positives_4: 16117.0000 - true_negatives_4: 53891.0000 - true_positives_4: 56284.0000 - val_loss: 0.4639 - val_acc: 0.7871 - val_precision_4: 0.8405 - val_recall_4: 0.7108 - val_auc_4: 0.8764 - val_false_negatives_4: 5727.0000 - val_false_positives_4: 2671.0000 - val_true_negatives_4: 16984.0000 - val_true_positives_4: 14073.0000 - lr: 5.0000e-04
# Epoch 4/5
# 4376/4376 [==============================] - 2150s 491ms/step - loss: 0.4461 - acc: 0.7885 - precision_4: 0.7794 - recall_4: 0.8048 - auc_4: 0.8715 - false_negatives_4: 13666.0000 - false_positives_4: 15946.0000 - true_negatives_4: 54062.0000 - true_positives_4: 56336.0000 - val_loss: 0.4670 - val_acc: 0.7851 - val_precision_4: 0.8459 - val_recall_4: 0.6993 - val_auc_4: 0.8768 - val_false_negatives_4: 5954.0000 - val_false_positives_4: 2523.0000 - val_true_negatives_4: 17132.0000 - val_true_positives_4: 13846.0000 - lr: 5.0000e-04
# Epoch 5/5
# 4376/4376 [==============================] - 2154s 492ms/step - loss: 0.4447 - acc: 0.7862 - precision_4: 0.7779 - recall_4: 0.8010 - auc_4: 0.8720 - false_negatives_4: 13928.0000 - false_positives_4: 16008.0000 - true_negatives_4: 54000.0000 - true_positives_4: 56074.0000 - val_loss: 0.4648 - val_acc: 0.7868 - val_precision_4: 0.8396 - val_recall_4: 0.7111 - val_auc_4: 0.8755 - val_false_negatives_4: 5721.0000 - val_false_positives_4: 2690.0000 - val_true_negatives_4: 16965.0000 - val_true_positives_4: 14079.0000 - lr: 5.0000e-04

# %%
# Evaluate last epoch Train and Test Loss and Accuracy scores
print(f"Train Loss: {h8.history['loss'][-1]}\n\
Val Loss: {h8.history['val_loss'][-1]}\n\
Train Acc: {h8.history['acc'][-1]}\n\
Val Acc: {h8.history['val_acc'][-1]}")
# Out:
# Train Loss: 0.4447440207004547
# Val Loss: 0.46476995944976807
# Train Acc: 0.786186695098877
# Val Acc: 0.7868204712867737

# %%
plt.figure(figsize= config.subplot_fig_size)

# Plot the loss
plt.subplot(2,2,1)
plt.plot(h7.history['loss'],label='Train Loss')
plt.plot(h7.history['val_loss'],label='Val Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model 7 Train and Val Loss')
plt.ylim(0, 1)

#Plot the Accuracy
plt.subplot(2,2,2)
plt.plot(h7.history['acc'],label='Train Accuracy')
plt.plot(h7.history['val_acc'],label='Val Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model 7 Train and Val Accuracy')
plt.ylim(0, 1)

# Save the plot as a PNG image
plt.savefig('model7.png')

# Display the plot
plt.show();

# %%
config.graph_me(h7, ['acc'])

plt.savefig('model7_r.png')

plt.show();

# %%
# serialize model to JSON
anna_model7_json = model7.to_json()
with open("anna_model7.json", "w") as json_file:
    json_file.write(anna_model7_json)

# serialize weights to HDF5
model7.save_weights("anna_model7.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model7.save('anna_model7_complete.h5')

# %%
df = pd.read_csv('../../Results/model_eval_anna.csv')

# Set 'models' column as the index
df.set_index('Unnamed: 0', inplace=True)

# Drop the row with index label 'models'
df.drop('models', inplace=True)

# Rename the index to 'models'
df.index.name = 'models'

df
# Out:
#          train_loss  train_acc  train_precision  train_recall  train_auc
# models
# model_1    0.046418   0.983007         0.981008      0.985086   0.998207  \
# model_2    0.027057   0.990694         0.990238      0.991157   0.999172
# model_3    0.037152   0.986929         0.986345      0.987529   0.998717
# model_4    0.036311   0.986794         0.986300      0.987300   0.998825
# model_5    0.092766   0.974295         0.973017      0.975644   0.996733
# model_6    0.135484   0.946475         0.943747      0.949544   0.988435
# model_7    0.466923   0.773538         0.764625      0.790349   0.857355
#
#          train_fn  train_fp  train_tn  train_tp  val_loss   val_acc
# models
# model_1    1044.0    1335.0   68666.0   68957.0  0.728149  0.859973  \
# model_2     619.0     684.0   69324.0   69383.0  0.457394  0.910100
# model_3     873.0     957.0   69051.0   69129.0  0.487295  0.792878
# model_4     889.0     960.0   69048.0   69113.0  0.260117  0.918135
# model_5    1705.0    1894.0   68114.0   68297.0  0.418766  0.878393
# model_6    3532.0    3962.0   66046.0   66470.0  0.286400  0.891167
# model_7   14676.0   17031.0   52977.0   55326.0  0.474107  0.779521
#
#          val_precision  val_recall   val_auc  val_fn  val_fp   val_tn   val_tp
# models
# model_1       0.848666    0.877445  0.918686  2425.0  3096.0  16545.0  17362.0
# model_2       0.876349    0.955707  0.957809   877.0  2670.0  16985.0  18923.0
# model_3       0.840637    0.724647  0.886185  5452.0  2720.0  16935.0  14348.0
# model_4       0.914167    0.923586  0.969956  1513.0  1717.0  17938.0  18287.0
# model_5       0.827841    0.956616  0.957764   859.0  3939.0  15716.0  18941.0
# model_6       0.887456    0.896869  0.956441  2042.0  2252.0  17403.0  17758.0
# model_7       0.822347    0.715152  0.865756  5640.0  3059.0  16596.0  14160.0

# %%
# Export the modified DataFrame to the same CSV file, replacing the existing file
#df.to_csv('../../Results/model_eval_anna.csv', index=False)

# %%
df_subset = df[['train_loss', 'train_acc', 'val_loss', 'val_acc']]
df_subset
# Out:
#          train_loss  train_acc  val_loss   val_acc
# models
# model_1    0.046418   0.983007  0.728149  0.859973
# model_2    0.027057   0.990694  0.457394  0.910100
# model_3    0.037152   0.986929  0.487295  0.792878
# model_4    0.036311   0.986794  0.260117  0.918135
# model_5    0.092766   0.974295  0.418766  0.878393
# model_6    0.135484   0.946475  0.286400  0.891167
# model_7    0.466923   0.773538  0.474107  0.779521

# %%
# Plotting bar chart
df_subset = df[['train_loss', 'train_acc', 'val_loss', 'val_acc']]

# Creating a subplot with two graphs
fig, axes = plt.subplots(2,1, figsize= config.subplot_fig_size)

# Plotting the train loss and val loss
df_subset[['train_loss', 'val_loss']].plot(kind='bar', ax=axes[0], rot=45)
axes[0].set_title('Train and Validation Loss')
axes[0].set_xlabel('Models')
axes[0].set_ylabel('Loss')
axes[0].legend(loc='upper right')

# Plotting the train acc and val acc
df_subset[['train_acc', 'val_acc']].plot(kind='bar', ax=axes[1], rot=45)
axes[1].set_title('Train and Validation Accuracy')
axes[1].set_xlabel('Models')
axes[1].set_ylabel('Accuracy')
axes[1].legend(loc='lower right')

plt.tight_layout()
plt.show();

# %% [markdown]
# Model 1 - 5 are CNN models that were hypertuned to achieve the best loss and accuracy scores.
# * Comparing all of the models' scores in Loss and Accuracy, it is clear that **model_4 performed the best**.
# * Model_4 had the lowest loss values and highest accuracy scores. The difference between the train and validation set for both scores were also minimal.
#
# Model 6 and 7 are CNN models that use transfer learning (EfficientNetV2L). Model 7 has an added image augmentation layer.
# * Comparing model 6 and 7, **model_6 performed the best**
# * While model_7 has very minimal difference between train and validation scores for both the loss and accuracy, model_6 had a much lower loss score and higher accuracy score.
#
#
# Model 4 and Model 7 will be the final two models that will be used moving forward from this notebook. These models will be compared to other models run in Reid and Chris's notebooks. This comparison can be found in the `Best_Models_NN.ipynb`

# %%
# Read the first CSV file
df1 = pd.read_csv('../../Results/model_eval_anna.csv')

# Read the second CSV file
df2 = pd.read_csv('../../Results/model_eval.csv')

display(df1)
display(df2)

# Join the two dataframes based on a common column
#merged_df = pd.merge(df1, df2, on = 'models')

# Check
#merged_df


# Write the merged dataframe to a new CSV file
#merged_df.to_csv('merged_file.csv', index=False)
# Out:
#   Unnamed: 0  train_loss  train_acc  train_precision  train_recall  train_auc
# 0     models         NaN        NaN              NaN           NaN        NaN  \
# 1    model_1    0.046418   0.983007         0.981008      0.985086   0.998207
# 2    model_2    0.027057   0.990694         0.990238      0.991157   0.999172
# 3    model_3    0.037152   0.986929         0.986345      0.987529   0.998717
# 4    model_4    0.036311   0.986794         0.986300      0.987300   0.998825
# 5    model_5    0.092766   0.974295         0.973017      0.975644   0.996733
# 6    model_6    0.135484   0.946475         0.943747      0.949544   0.988435
# 7    model_7    0.466923   0.773538         0.764625      0.790349   0.857355
#
#    train_fn  train_fp  train_tn  train_tp  val_loss   val_acc  val_precision
# 0       NaN       NaN       NaN       NaN       NaN       NaN            NaN  \
# 1    1044.0    1335.0   68666.0   68957.0  0.728149  0.859973       0.848666
# 2     619.0     684.0   69324.0   69383.0  0.457394  0.910100       0.876349
# 3     873.0     957.0   69051.0   69129.0  0.487295  0.792878       0.840637
# 4     889.0     960.0   69048.0   69113.0  0.260117  0.918135       0.914167
# 5    1705.0    1894.0   68114.0   68297.0  0.418766  0.878393       0.827841
# 6    3532.0    3962.0   66046.0   66470.0  0.286400  0.891167       0.887456
# 7   14676.0   17031.0   52977.0   55326.0  0.474107  0.779521       0.822347
#
#    val_recall   val_auc  val_fn  val_fp   val_tn   val_tp
# 0         NaN       NaN     NaN     NaN      NaN      NaN
# 1    0.877445  0.918686  2425.0  3096.0  16545.0  17362.0
# 2    0.955707  0.957809   877.0  2670.0  16985.0  18923.0
# 3    0.724647  0.886185  5452.0  2720.0  16935.0  14348.0
# 4    0.923586  0.969956  1513.0  1717.0  17938.0  18287.0
# 5    0.956616  0.957764   859.0  3939.0  15716.0  18941.0
# 6    0.896869  0.956441  2042.0  2252.0  17403.0  17758.0
# 7    0.715152  0.865756  5640.0  3059.0  16596.0  14160.0
#                   Unnamed: 0  train_loss  train_acc  train_precision
# 0                     models         NaN        NaN              NaN  \
# 1                    model_1    0.046418   0.983007         0.981008
# 2  efficientnetv2-b0_retrain    0.003119   0.977746         0.994270
# 3                   cnn_reid    0.052528   0.978279         0.998641
# 4               cnn_baseline    0.202000   0.917600         0.910000
#
#    train_recall  train_auc  train_fn  train_fp  train_tn  train_tp  val_loss
# 0           NaN        NaN       NaN       NaN       NaN       NaN       NaN  \
# 1      0.985086   0.998207    1044.0    1335.0   68666.0   68957.0  0.728149
# 2      0.963431   0.993228   86257.0   89180.0    3385.0     608.0  0.119601
# 3      0.963815   0.993872   67389.0   69572.0    2612.0     429.0  0.367717
# 4      0.927000   0.974700    5112.0    6418.0   63583.0   64889.0  0.421600
#
#     val_acc  val_precision  val_recall   val_auc   val_fn   val_fp   val_tn
# 0       NaN            NaN         NaN       NaN      NaN      NaN      NaN  \
# 1  0.859973       0.848666    0.877445  0.918686   2425.0   3096.0  16545.0
# 2  0.965126       0.991854    0.949819  0.982413  18614.0  19439.0   1027.0
# 3  0.902252       0.965261    0.853517  0.972052  16340.0  19234.0   3301.0
# 4  0.821600       0.772300    0.913900  0.916900   1704.0   5331.0  14310.0
#
#     val_tp
# 0      NaN
# 1  17362.0
# 2    348.0
# 3    553.0
# 4  18083.0

# %%
# Join the two dataframes based on a common column
merged_df = pd.merge(df1, df2, how = 'outer')
merged_df
# Out:
#                    Unnamed: 0  train_loss  train_acc  train_precision
# 0                      models         NaN        NaN              NaN  \
# 1                     model_1    0.046418   0.983007         0.981008
# 2                     model_2    0.027057   0.990694         0.990238
# 3                     model_3    0.037152   0.986929         0.986345
# 4                     model_4    0.036311   0.986794         0.986300
# 5                     model_5    0.092766   0.974295         0.973017
# 6                     model_6    0.135484   0.946475         0.943747
# 7                     model_7    0.466923   0.773538         0.764625
# 8                     model_1    0.046418   0.983007         0.981008
# 9   efficientnetv2-b0_retrain    0.003119   0.977746         0.994270
# 10                   cnn_reid    0.052528   0.978279         0.998641
# 11               cnn_baseline    0.202000   0.917600         0.910000
#
#     train_recall  train_auc  train_fn  train_fp  train_tn  train_tp  val_loss
# 0            NaN        NaN       NaN       NaN       NaN       NaN       NaN  \
# 1       0.985086   0.998207    1044.0    1335.0   68666.0   68957.0  0.728149
# 2       0.991157   0.999172     619.0     684.0   69324.0   69383.0  0.457394
# 3       0.987529   0.998717     873.0     957.0   69051.0   69129.0  0.487295
# 4       0.987300   0.998825     889.0     960.0   69048.0   69113.0  0.260117
# 5       0.975644   0.996733    1705.0    1894.0   68114.0   68297.0  0.418766
# 6       0.949544   0.988435    3532.0    3962.0   66046.0   66470.0  0.286400
# 7       0.790349   0.857355   14676.0   17031.0   52977.0   55326.0  0.474107
# 8       0.985086   0.998207    1044.0    1335.0   68666.0   68957.0  0.728149
# 9       0.963431   0.993228   86257.0   89180.0    3385.0     608.0  0.119601
# 10      0.963815   0.993872   67389.0   69572.0    2612.0     429.0  0.367717
# 11      0.927000   0.974700    5112.0    6418.0   63583.0   64889.0  0.421600
#
#      val_acc  val_precision  val_recall   val_auc   val_fn   val_fp   val_tn
# 0        NaN            NaN         NaN       NaN      NaN      NaN      NaN  \
# 1   0.859973       0.848666    0.877445  0.918686   2425.0   3096.0  16545.0
# 2   0.910100       0.876349    0.955707  0.957809    877.0   2670.0  16985.0
# 3   0.792878       0.840637    0.724647  0.886185   5452.0   2720.0  16935.0
# 4   0.918135       0.914167    0.923586  0.969956   1513.0   1717.0  17938.0
# 5   0.878393       0.827841    0.956616  0.957764    859.0   3939.0  15716.0
# 6   0.891167       0.887456    0.896869  0.956441   2042.0   2252.0  17403.0
# 7   0.779521       0.822347    0.715152  0.865756   5640.0   3059.0  16596.0
# 8   0.859973       0.848666    0.877445  0.918686   2425.0   3096.0  16545.0
# 9   0.965126       0.991854    0.949819  0.982413  18614.0  19439.0   1027.0
# 10  0.902252       0.965261    0.853517  0.972052  16340.0  19234.0   3301.0
# 11  0.821600       0.772300    0.913900  0.916900   1704.0   5331.0  14310.0
#
#      val_tp
# 0       NaN
# 1   17362.0
# 2   18923.0
# 3   14348.0
# 4   18287.0
# 5   18941.0
# 6   17758.0
# 7   14160.0
# 8   17362.0
# 9     348.0
# 10    553.0
# 11  18083.0

# %%
# Set 'models' column as the index
merged_df.set_index('Unnamed: 0', inplace=True)

# Drop the row with index label 'models'
merged_df.drop(['models','model_1', 'model_2', 'model_3', 'model_5', 'model_7'] inplace=True)

# Rename the index to 'models'
merged_df.index.name = 'models'

merged_df
# Out:
#                            train_loss  train_acc  train_precision
# models
# model_4                      0.036311   0.986794         0.986300  \
# model_6                      0.135484   0.946475         0.943747
# efficientnetv2-b0_retrain    0.003119   0.977746         0.994270
# cnn_reid                     0.052528   0.978279         0.998641
# cnn_baseline                 0.202000   0.917600         0.910000
#
#                            train_recall  train_auc  train_fn  train_fp
# models
# model_4                        0.987300   0.998825     889.0     960.0  \
# model_6                        0.949544   0.988435    3532.0    3962.0
# efficientnetv2-b0_retrain      0.963431   0.993228   86257.0   89180.0
# cnn_reid                       0.963815   0.993872   67389.0   69572.0
# cnn_baseline                   0.927000   0.974700    5112.0    6418.0
#
#                            train_tn  train_tp  val_loss   val_acc
# models
# model_4                     69048.0   69113.0  0.260117  0.918135  \
# model_6                     66046.0   66470.0  0.286400  0.891167
# efficientnetv2-b0_retrain    3385.0     608.0  0.119601  0.965126
# cnn_reid                     2612.0     429.0  0.367717  0.902252
# cnn_baseline                63583.0   64889.0  0.421600  0.821600
#
#                            val_precision  val_recall   val_auc   val_fn
# models
# model_4                         0.914167    0.923586  0.969956   1513.0  \
# model_6                         0.887456    0.896869  0.956441   2042.0
# efficientnetv2-b0_retrain       0.991854    0.949819  0.982413  18614.0
# cnn_reid                        0.965261    0.853517  0.972052  16340.0
# cnn_baseline                    0.772300    0.913900  0.916900   1704.0
#
#                             val_fp   val_tn   val_tp
# models
# model_4                     1717.0  17938.0  18287.0
# model_6                     2252.0  17403.0  17758.0
# efficientnetv2-b0_retrain  19439.0   1027.0    348.0
# cnn_reid                   19234.0   3301.0    553.0
# cnn_baseline                5331.0  14310.0  18083.0

# %%
merged_df.to_csv('../../Results/model_eval.csv')

# %%
merged_df = pd.read_csv('../../Results/model_eval.csv')
merged_df
# Out:
#                       models  train_loss  train_acc  train_precision
# 0                    model_4    0.036311   0.986794         0.986300  \
# 1                    model_6    0.135484   0.946475         0.943747
# 2  efficientnetv2-b0_retrain    0.003119   0.977746         0.994270
# 3                   cnn_reid    0.052528   0.978279         0.998641
# 4               cnn_baseline    0.202000   0.917600         0.910000
#
#    train_recall  train_auc  train_fn  train_fp  train_tn  train_tp  val_loss
# 0      0.987300   0.998825     889.0     960.0   69048.0   69113.0  0.260117  \
# 1      0.949544   0.988435    3532.0    3962.0   66046.0   66470.0  0.286400
# 2      0.963431   0.993228   86257.0   89180.0    3385.0     608.0  0.119601
# 3      0.963815   0.993872   67389.0   69572.0    2612.0     429.0  0.367717
# 4      0.927000   0.974700    5112.0    6418.0   63583.0   64889.0  0.421600
#
#     val_acc  val_precision  val_recall   val_auc   val_fn   val_fp   val_tn
# 0  0.918135       0.914167    0.923586  0.969956   1513.0   1717.0  17938.0  \
# 1  0.891167       0.887456    0.896869  0.956441   2042.0   2252.0  17403.0
# 2  0.965126       0.991854    0.949819  0.982413  18614.0  19439.0   1027.0
# 3  0.902252       0.965261    0.853517  0.972052  16340.0  19234.0   3301.0
# 4  0.821600       0.772300    0.913900  0.916900   1704.0   5331.0  14310.0
#
#     val_tp
# 0  18287.0
# 1  17758.0
# 2    348.0
# 3    553.0
# 4  18083.0

# %%
merged_df.loc[[0, 1, 2, 4], 'models'] = ['cnn_tuned', 'effnetv2L', 'effnetv2b0', 'cnn_benchmark']
merged_df.drop(3, inplace=True)

merged_df
# Out:
#           models  train_loss  train_acc  train_precision  train_recall
# 0      cnn_tuned    0.036311   0.986794         0.986300      0.987300  \
# 1      effnetv2L    0.135484   0.946475         0.943747      0.949544
# 2     effnetv2b0    0.003119   0.977746         0.994270      0.963431
# 4  cnn_benchmark    0.202000   0.917600         0.910000      0.927000
#
#    train_auc  train_fn  train_fp  train_tn  train_tp  val_loss   val_acc
# 0   0.998825     889.0     960.0   69048.0   69113.0  0.260117  0.918135  \
# 1   0.988435    3532.0    3962.0   66046.0   66470.0  0.286400  0.891167
# 2   0.993228   86257.0   89180.0    3385.0     608.0  0.119601  0.965126
# 4   0.974700    5112.0    6418.0   63583.0   64889.0  0.421600  0.821600
#
#    val_precision  val_recall   val_auc   val_fn   val_fp   val_tn   val_tp
# 0       0.914167    0.923586  0.969956   1513.0   1717.0  17938.0  18287.0
# 1       0.887456    0.896869  0.956441   2042.0   2252.0  17403.0  17758.0
# 2       0.991854    0.949819  0.982413  18614.0  19439.0   1027.0    348.0
# 4       0.772300    0.913900  0.916900   1704.0   5331.0  14310.0  18083.0

# %%
merged_df.to_csv('../../Results/model_eval.csv')
